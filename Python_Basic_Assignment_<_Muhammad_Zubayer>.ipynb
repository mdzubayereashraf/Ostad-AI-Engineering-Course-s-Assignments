# %% [markdown]
# <a href="https://colab.research.google.com/github/mdzubayereashraf/Ostad-AI-Engineering-Course-s-Assignments/blob/main/Python_Basic_Assignment_%3C_Muhammad_Zubayer%3E.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Answer to the question no. 1**

# %%
print("Welcome to Python Programming.\nI am learning the basics.")
# Out:
# Welcome to Python Programming.
# I am learning the basics.

# %% [markdown]
# **Answer to the question no. 2**

# %%
name = "Muhammad Zubayer"
age = 25
print(f"My name is {name} and I am {age} years old.")
# Out:
# My name is Muhammad Zubayer and I am 25 years old.

# %% [markdown]
# **Answer to the question no. 3**

# %%
Name = input("Enter your name: ")
F_P_language = input("Enter your favourite programming language: ")
print(f"Hello {Name}, Your favourite language is {F_P_language}.")
# Out:
# Enter your name: gg
# Enter your favourite programming language: gg
# Hello gg, Your favourite language is gg.

# %% [markdown]
# **Answer to the question no. 4**

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))
print(f"The sum is: {num1 + num2}.")
# Out:
# Enter first number: 25
# Enter second number: 25
# The sum is: 50.

# %% [markdown]
# **Answer to the question no. 5**

# %%
num1 = float(input("Enter a number: "))
num2 = float(input("Enter another number: "))
sum = num1+num2
minus = num1-num2
multiply = num1*num2
print(f"Additon is: {sum}")
print(f"Subtraction is: {minus}")
print(f"Multiplication is: {multiply}")
# Out:
# Enter a number: 25
# Enter another number: 25
# Additon is: 50.0
# Subtraction is: 0.0
# Multiplication is: 625.0
